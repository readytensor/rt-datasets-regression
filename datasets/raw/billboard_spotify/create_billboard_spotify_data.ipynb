# %%
import numpy as np
import pandas as pd
import os

# %%
dataset_name = 'billboard_spotify'

# %%
input_dir = './data'
inp_fname = 'music.csv'
output_dir = f'./../../processed/{dataset_name}/'
outp_fname = os.path.join(output_dir, f'{dataset_name}.csv')

# %% [markdown]
# # Read Data

# %%
data = pd.read_csv(os.path.join(input_dir, inp_fname))
data.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0        0.0729  0.0137    0   -22.812     0       0.0470      0.979000
# 1        0.1300  0.9910   11    -3.126     1       0.0604      0.000012
# 2        0.1630  0.8850    5    -4.623     0       0.0725      0.000202
# 3        0.1720  0.2720    2   -10.081     0       0.0318      0.944000
# 4        0.2000  0.1440    0   -19.048     1       0.0461      0.002250
#
#    instrumentalness  liveness  valence  ...  time_signature  \
# 0          0.956000    0.0869   0.0370  ...               5
# 1          0.004120    0.2250   0.5050  ...               4
# 2          0.012100    0.2280   0.5490  ...               3
# 3          0.000172    0.1410   0.2970  ...               3
# 4          0.942000    0.2210   0.0262  ...               4
#
#                track_name          artists_names release_date country-songs  \
# 0  Litanie contre la Peur               ['TOOL']    8/30/2019             0
# ...

# %%
data.shape
# Out:
# (8930, 27)

# %%
id_col = "id"
target_col = "danceability"

# %% [markdown]
# # Prepare Data

# %%
data.columns
# Out:
# Index(['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'type', 'id', 'uri', 'track_href', 'analysis_url', 'duration_ms',
#        'time_signature', 'track_name', 'artists_names', 'release_date',
#        'country-songs', 'dance-electronic-songs', 'hot-rock-songs',
#        'jazz-songs', 'latin-songs', 'r-b-hip-hop-songs'],
#       dtype='object')

# %%
cols_to_use = ['id', 'energy', 'key', 'loudness', 'mode', 'speechiness',
       'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
       'duration_ms', 'time_signature', 'country-songs', 'dance-electronic-songs', 'hot-rock-songs',
       'jazz-songs', 'latin-songs', 'r-b-hip-hop-songs', 'danceability']

# %%
data = data[cols_to_use]

# %%
# Drop duplicates
data = data.drop_duplicates()

# %%
data.head()
# Out:
#                        id  energy  key  loudness  mode  speechiness  \
# 0  4qE9yOgBNsARadpZTAb6RH  0.0137    0   -22.812     0       0.0470
# 1  7myke8Id4WyKFlWcRBJdIF  0.9910   11    -3.126     1       0.0604
# 2  597i9UhHbW8hHgBUp8Tm54  0.8850    5    -4.623     0       0.0725
# 3  5sCM5Umhh58exttFcux31W  0.2720    2   -10.081     0       0.0318
# 4  48C0O5CXfQdfjUCUhOs1YP  0.1440    0   -19.048     1       0.0461
#
#    acousticness  instrumentalness  liveness  valence    tempo  duration_ms  \
# 0      0.979000          0.956000    0.0869   0.0370   78.824       134490
# 1      0.000012          0.004120    0.2250   0.5050  185.364       191332
# 2      0.000202          0.012100    0.2280   0.5490  198.556       343907
# 3      0.944000          0.000172    0.1410   0.2970  171.850       156056
# 4      0.002250          0.942000    0.2210   0.0262   79.702       189979
#
#    time_signature  country-songs  dance-electronic-songs  hot-rock-songs  \
# ...

# %% [markdown]
# # Save Main Data File

# %%
data.to_csv(outp_fname, index=False)
