# %%
import numpy as np
import pandas as pd
import os
import json
import pprint

# %%
dataset_name = 'computer_activity'

# %%
input_dir = './raw'
output_dir = './processed'

inp_fname = 'cpu_act.data'

outp_fname = os.path.join(output_dir, f'{dataset_name}.csv')
outp_train_fname = os.path.join(output_dir, f'{dataset_name}_train.csv')
outp_test_fname = os.path.join(output_dir, f'{dataset_name}_test.csv')
outp_test_key_fname = os.path.join(output_dir, f'{dataset_name}_test_key.csv')
outp_infer_instances = os.path.join(output_dir, f'{dataset_name}_infer_req.json')

# %% [markdown]
# # Read Data

# %%
col_names = [
    'lread', 
    'lwrite', 
    'scall', 
    'sread', 
    'swrite', 
    'fork', 
    'exec', 
    'rchar', 
    'wchar', 
    'pgout', 
    'ppgout', 
    'pgfree', 
    'pgscan', 
    'atch', 
    'pgin', 
    'ppgin', 
    'pflt', 
    'vflt', 
    'runqsz', 
    'freemem', 
    'freeswap', 
    'usr',   
]

# %%
data = pd.read_csv(os.path.join(input_dir, inp_fname), header=None,names=col_names)
data.head()
# Out:
#    lread  lwrite  scall  sread  swrite  fork  exec   rchar   wchar  pgout  \
# 0      6       2   1036    103     114  1.00  1.00  172076  355965   0.00
# 1      1       0   2165    205     101  0.40  1.20   43107   44139   4.80
# 2     62      77   3806    258     166  1.40  1.40  492142  268706   4.80
# 3      5       0   4721    256     177  0.99  2.58  524787  174964  14.51
# 4     42      55   3949    249     244  2.60  4.60  197289  529200   4.20
#
#    ...  pgscan  atch   pgin  ppgin    pflt    vflt  runqsz  freemem  freeswap  \
# 0  ...    0.00  0.00   2.00   4.00   73.60   89.00     2.0     6527   1851864
# 1  ...  181.40  0.20  85.40  88.20   19.40  161.80     3.0      130   1131931
# 2  ...   79.20  2.20   7.60  12.20   68.00  218.80     5.2      256   1314590
# 3  ...  189.86  1.99   4.17  24.85   95.63  248.91     1.0      233    972606
# 4  ...    0.00  1.40   1.80   2.20  219.60  297.20     3.4      331   1013805
#
#    usr
# 0   90
# 1   88
# 2   85
# 3   81
# 4   79
#
# [5 rows x 22 columns]

# %%
id_col = "id"
target_col = "usr"

# %%
data[target_col].value_counts()
# Out:
# 90    459
# 91    448
# 92    426
# 94    421
# 93    411
# 97    410
# 96    410
# 95    405
# 88    384
# 98    378
# 89    376
# 87    338
# 86    283
# 0     283
# 85    254
# 84    252
# 83    230
# 81    201
# 82    187
# 80    166
# 79    150
# 77    144
# 78    126
# 76    119
# 75    104
# 74     96
# 72     77
# 73     73
# 99     60
# 69     51
# 71     49
# 68     46
# 70     42
# 67     39
# 66     36
# 63     32
# 64     27
# 62     27
# 65     25
# 59     23
# 60     20
# 58     17
# 61     16
# 57     14
# 56     11
# 55     10
# 1      10
# 54      7
# 53      5
# 51      4
# 50      4
# 52      2
# 46      1
# 49      1
# 48      1
# 2       1
# Name: usr, dtype: int64

# %% [markdown]
# # Shuffle Data

# %%
# shuffle data
data = data.sample(frac=1, random_state=42)
data.head()
# Out:
#       lread  lwrite  scall  sread  swrite  fork  exec   rchar  wchar  pgout  \
# 5670      1       0    400     45      49   1.2   1.2   40302  24635   0.00
# 5369     14       0    806    101      60   0.4   0.4  175267   8453   3.39
# 2111     13       1   4137    197      96  10.2  33.6  209720  39281   6.60
# 6659      0       0   1498    172      43   0.2   0.2   13410  23242   0.00
# 5227     19       9   3744    393     329   6.8   4.4  209666  21515   1.00
#
#       ...  pgscan  atch  pgin  ppgin    pflt   vflt  runqsz  freemem  \
# 5670  ...    0.00   0.0  0.40   0.60   86.20  106.0     2.0     4062
# 5369  ...   91.42   0.6  9.58  27.15   23.15   99.2     2.4      137
# 2111  ...    9.40   3.8  3.80   3.80  542.60  838.0     1.0      226
# 6659  ...    0.00   0.0  0.00   0.00   15.60   16.8     1.6     5805
# 5227  ...   37.20   0.6  6.20   6.20  356.40  572.2     1.3      235
#
#       freeswap  usr
# 5670   1779392   91
# 5369   1735008   84
# 2111   1032648   62
# 6659   1818256   94
# 5227   1073950   80
#
# [5 rows x 22 columns]

# %% [markdown]
# # Insert Id Column

# %%
# insert Id column 
if id_col not in data.columns:
    N = data.shape[0]
    data.insert(0, id_col, np.arange(N))
    print(data.head())
data[id_col] = data[id_col].astype(str)
# Out:
#       id  lread  lwrite  scall  sread  swrite  fork  exec   rchar  wchar  ...  \
# 5670   0      1       0    400     45      49   1.2   1.2   40302  24635  ...
# 5369   1     14       0    806    101      60   0.4   0.4  175267   8453  ...
# 2111   2     13       1   4137    197      96  10.2  33.6  209720  39281  ...
# 6659   3      0       0   1498    172      43   0.2   0.2   13410  23242  ...
# 5227   4     19       9   3744    393     329   6.8   4.4  209666  21515  ...
#
#       pgscan  atch  pgin  ppgin    pflt   vflt  runqsz  freemem  freeswap  usr
# 5670    0.00   0.0  0.40   0.60   86.20  106.0     2.0     4062   1779392   91
# 5369   91.42   0.6  9.58  27.15   23.15   99.2     2.4      137   1735008   84
# 2111    9.40   3.8  3.80   3.80  542.60  838.0     1.0      226   1032648   62
# 6659    0.00   0.0  0.00   0.00   15.60   16.8     1.6     5805   1818256   94
# 5227   37.20   0.6  6.20   6.20  356.40  572.2     1.3      235   1073950   80
#
# [5 rows x 23 columns]

# %% [markdown]
# # Save Main Data File

# %%
data.to_csv(outp_fname, index=False)

# %% [markdown]
# # Train Test Split

# %%
from sklearn.model_selection import train_test_split
test_size = 0.1

data_train, data_test = train_test_split(data, test_size=test_size, random_state=42)
print(data_train.shape, data_test.shape)

data_train.to_csv(outp_train_fname, index=False)
data_test.drop(columns=[target_col]).to_csv(outp_test_fname, index=False)
data_test[[id_col, target_col]].to_csv(outp_test_key_fname, index=False)
# Out:
# (7372, 23) (820, 23)

# %% [markdown]
# # JSON inference request instance

# %%
instance = data_test.replace({np.nan:None}).drop(columns=[target_col]).reset_index(drop=True).loc[0].to_dict()
infer_req_instance_dict = {  "instances": [ {**instance}, ] }
pprint.pprint(infer_req_instance_dict)
   
with open(outp_infer_instances, 'w', encoding='utf8') as f:
    json.dump(infer_req_instance_dict, f, indent=2, ensure_ascii=False)
# Out:
# {'instances': [{'atch': 0.0,
#                 'exec': 0.2,
#                 'fork': 0.2,
#                 'freemem': 1333,
#                 'freeswap': 1713242,
#                 'id': '5670',
#                 'lread': 3,
#                 'lwrite': 1,
#                 'pflt': 22.6,
#                 'pgfree': 0.0,
#                 'pgin': 0.2,
#                 'pgout': 0.0,
#                 'pgscan': 0.0,
#                 'ppgin': 0.2,
#                 'ppgout': 0.0,
#                 'rchar': 45128,
#                 'runqsz': 2.0,
#                 'scall': 540,
#                 'sread': 96,
#                 'swrite': 88,
#                 'vflt': 17.4,
#                 'wchar': 56460}]}
